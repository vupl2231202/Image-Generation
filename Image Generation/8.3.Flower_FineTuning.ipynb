# %%
# download data: https://drive.google.com/file/d/11Buzytn4vIh4x_Oqz8MY29JMMdIqSzj-/view?usp=share_link

# %% [markdown]
# # Fine-tuning

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf

from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
PATH = 'flower_photos/'

train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

BATCH_SIZE = 256
IMG_SIZE = (160, 160)
BUFFER_SIZE = BATCH_SIZE*5

train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
                                              PATH,
                                              validation_split=0.2,
                                              subset="training",
                                              seed=123,
                                              image_size=IMG_SIZE,
                                              batch_size=BATCH_SIZE)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.

# %%
validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
                                                  PATH,
                                                  validation_split=0.2,
                                                  subset="validation",
                                                  seed=123,
                                                  image_size=IMG_SIZE,
                                                  batch_size=BATCH_SIZE)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
train_dataset = train_dataset.prefetch(buffer_size=BUFFER_SIZE)
validation_dataset = validation_dataset.prefetch(buffer_size=BUFFER_SIZE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %%
preprocess_input = tf.keras.applications.vgg16.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)

# %%
print(IMG_SIZE)
IMG_SHAPE = IMG_SIZE + (3,)
print(IMG_SHAPE)
# Out:
# (160, 160)
# (160, 160, 3)

# %%
# Create the base model from the pre-trained model MobileNet V2
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (256, 5, 5, 512)

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (256, 512)

# %%
prediction_layer = tf.keras.layers.Dense(5)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (256, 5)

# %%
inputs = tf.keras.Input(shape=(160, 160, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %% [markdown]
# ### Un-freeze the top layers of the model

# %% [markdown]
# All you need to do is unfreeze the `base_model` and set the bottom layers to be un-trainable. Then, you should recompile the model (necessary for these changes to take effect), and resume training.

# %%
base_model.trainable = True
# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(base_model.layers))
# Out:
# Number of layers in the base model:  19

# %%
# Fine-tune from this layer onwards
fine_tune_at = 14

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable =  False

# %%
base_learning_rate = 0.0001
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.Adam(lr=base_learning_rate),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 160, 160, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 160, 160, 3)       0
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 160, 160, 3)]     0
# _________________________________________________________________
# tf_op_layer_BiasAdd (TensorF [(None, 160, 160, 3)]     0
# _________________________________________________________________
# vgg16 (Functional)           (None, 5, 5, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 2565
# =================================================================
# Total params: 14,717,253
# Trainable params: 7,081,989
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 8

# %%
history_fine = model.fit(train_dataset,
                         epochs=150,
                         validation_data=validation_dataset)
# Out:
# Epoch 1/150
# 12/12 [==============================] - 7s 574ms/step - loss: 2.5644 - accuracy: 0.3859 - val_loss: 1.1356 - val_accuracy: 0.5477
# Epoch 2/150
# 12/12 [==============================] - 4s 334ms/step - loss: 1.0635 - accuracy: 0.5933 - val_loss: 0.6518 - val_accuracy: 0.7725
# Epoch 3/150
# 12/12 [==============================] - 4s 336ms/step - loss: 0.7342 - accuracy: 0.7197 - val_loss: 0.5015 - val_accuracy: 0.8174
# Epoch 4/150
# 12/12 [==============================] - 4s 334ms/step - loss: 0.5816 - accuracy: 0.7820 - val_loss: 0.4614 - val_accuracy: 0.8406
# Epoch 5/150
150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.3296 - val_accuracy: 0.9346
# Epoch 92/150
# 12/12 [==============================] - 4s 337ms/step - loss: 0.0120 - accuracy: 0.9959 - val_loss: 0.3513 - val_accuracy: 0.9319
# Epoch 93/150
# 12/12 [==============================] - 4s 337ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.4279 - val_accuracy: 0.9305
# Epoch 94/150
# 12/12 [==============================] - 4s 336ms/step - loss: 0.0111 - accuracy: 0.9969 - val_loss: 0.4878 - val_accuracy: 0.9251
# Epoch 95/150
# 12/12 [==============================] - 4s 344ms/step - loss: 0.0201 - accuracy: 0.9932 - val_loss: 0.4407 - val_accuracy: 0.9155
# Epoch 96/150
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0112 - accuracy: 0.9976 - val_loss: 0.4092 - val_accuracy: 0.9332
# Epoch 97/150
# 12/12 [==============================] - 4s 340ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.4005 - val_accuracy: 0.9292
# Epoch 98/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0058 - accuracy: 0.9976 - val_loss: 0.4577 - val_accuracy: 0.9346
# Epoch 99/150
# 12/12 [==============================] - 4s 340ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.4890 - val_accuracy: 0.9360
# Epoch 100/150
# 12/12 [==============================] - 4s 337ms/step - loss: 0.0108 - accuracy: 0.9949 - val_loss: 0.4528 - val_accuracy: 0.9319
# Epoch 101/150
# 12/12 [==============================] - 4s 340ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.4664 - val_accuracy: 0.9237
# Epoch 102/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0316 - accuracy: 0.9928 - val_loss: 0.3498 - val_accuracy: 0.9346
# Epoch 103/150
# 12/12 [==============================] - 4s 344ms/step - loss: 0.0172 - accuracy: 0.9946 - val_loss: 0.4847 - val_accuracy: 0.9155
# Epoch 104/150
# 12/12 [==============================] - 4s 345ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.4314 - val_accuracy: 0.9196
# Epoch 105/150
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0106 - accuracy: 0.9969 - val_loss: 0.4088 - val_accuracy: 0.9305
# Epoch 106/150
# 12/12 [==============================] - 4s 337ms/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.3038 - val_accuracy: 0.9428
# Epoch 107/150
# 12/12 [==============================] - 4s 337ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.3989 - val_accuracy: 0.9332
# Epoch 108/150
# 12/12 [==============================] - 4s 341ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.4072 - val_accuracy: 0.9278
# Epoch 109/150
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.4109 - val_accuracy: 0.9264
# Epoch 110/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0081 - accuracy: 0.9986 - val_loss: 0.3909 - val_accuracy: 0.9251
# Epoch 111/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0206 - accuracy: 0.9932 - val_loss: 0.4798 - val_accuracy: 0.9183
# Epoch 112/150
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0131 - accuracy: 0.9956 - val_loss: 0.4029 - val_accuracy: 0.9237
# Epoch 113/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0103 - accuracy: 0.9976 - val_loss: 0.4272 - val_accuracy: 0.9251
# Epoch 114/150
# 12/12 [==============================] - 4s 337ms/step - loss: 0.0090 - accuracy: 0.9976 - val_loss: 0.4355 - val_accuracy: 0.9237
# Epoch 115/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.4556 - val_accuracy: 0.9210
# Epoch 116/150
# 12/12 [==============================] - 4s 340ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.4436 - val_accuracy: 0.9373
# Epoch 117/150
# 12/12 [==============================] - 4s 342ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.4096 - val_accuracy: 0.9360
# Epoch 118/150
# 12/12 [==============================] - 4s 341ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.3730 - val_accuracy: 0.9373
# Epoch 119/150
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0053 - accuracy: 0.9976 - val_loss: 0.4046 - val_accuracy: 0.9346
# Epoch 120/150
# 12/12 [==============================] - 4s 337ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.5115 - val_accuracy: 0.9278
# Epoch 121/150
# 12/12 [==============================] - 4s 340ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.4492 - val_accuracy: 0.9319
# Epoch 122/150
# 12/12 [==============================] - 4s 336ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.4695 - val_accuracy: 0.9360
# Epoch 123/150
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 0.4462 - val_accuracy: 0.9360
# Epoch 124/150
# 12/12 [==============================] - 4s 336ms/step - loss: 0.0024 - accuracy: 0.9986 - val_loss: 0.5010 - val_accuracy: 0.9387
# Epoch 125/150
# 12/12 [==============================] - 4s 343ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.4302 - val_accuracy: 0.9414
# Epoch 126/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.4797 - val_accuracy: 0.9305
# Epoch 127/150
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0042 - accuracy: 0.9993 - val_loss: 0.4263 - val_accuracy: 0.9292
# Epoch 128/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.4955 - val_accuracy: 0.9278
# Epoch 129/150
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.4501 - val_accuracy: 0.9278
# Epoch 130/150
# 12/12 [==============================] - 4s 337ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.4305 - val_accuracy: 0.9278
# Epoch 131/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.5097 - val_accuracy: 0.9278
# Epoch 132/150
# 12/12 [==============================] - 4s 338ms/step - loss: 9.8689e-04 - accuracy: 1.0000 - val_loss: 0.4968 - val_accuracy: 0.9305
# Epoch 133/150
# 12/12 [==============================] - 4s 337ms/step - loss: 9.8194e-04 - accuracy: 0.9997 - val_loss: 0.6027 - val_accuracy: 0.9210
# Epoch 134/150
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 0.6417 - val_accuracy: 0.9223
# Epoch 135/150
# 12/12 [==============================] - 4s 338ms/step - loss: 8.8055e-04 - accuracy: 1.0000 - val_loss: 0.5036 - val_accuracy: 0.9387
# Epoch 136/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.6343 - val_accuracy: 0.9155
# Epoch 137/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0156 - accuracy: 0.9952 - val_loss: 0.5305 - val_accuracy: 0.9210
# Epoch 138/150
# 12/12 [==============================] - 4s 340ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.4603 - val_accuracy: 0.9332
# Epoch 139/150
# 12/12 [==============================] - 4s 350ms/step - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.7113 - val_accuracy: 0.9237
# Epoch 140/150
# 12/12 [==============================] - 4s 337ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.4518 - val_accuracy: 0.9278
# Epoch 141/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0166 - accuracy: 0.9942 - val_loss: 0.5258 - val_accuracy: 0.9142
# Epoch 142/150
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0243 - accuracy: 0.9922 - val_loss: 0.5735 - val_accuracy: 0.9264
# Epoch 143/150
# 12/12 [==============================] - 4s 342ms/step - loss: 0.0438 - accuracy: 0.9915 - val_loss: 0.3883 - val_accuracy: 0.9223
# Epoch 144/150
# 12/12 [==============================] - 4s 340ms/step - loss: 0.0204 - accuracy: 0.9942 - val_loss: 0.4473 - val_accuracy: 0.9264
# Epoch 145/150
# 12/12 [==============================] - 4s 344ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.5722 - val_accuracy: 0.9237
# Epoch 146/150
# 12/12 [==============================] - 4s 341ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4508 - val_accuracy: 0.9332
# Epoch 147/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.4841 - val_accuracy: 0.9305
# Epoch 148/150
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4623 - val_accuracy: 0.9292
# Epoch 149/150
# 12/12 [==============================] - 4s 347ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.4537 - val_accuracy: 0.9292
# Epoch 150/150
# 12/12 [==============================] - 4s 340ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.4585 - val_accuracy: 0.9305

# %%
acc = history_fine.history['accuracy']
val_acc = history_fine.history['val_accuracy']

loss = history_fine.history['loss']
val_loss = history_fine.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0.8, 1])
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 1.0])
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## Summary
#
# * **Using a pre-trained model for feature extraction**:  When working with a small dataset, it is a common practice to take advantage of features learned by a model trained on a larger dataset in the same domain. This is done by instantiating the pre-trained model and adding a fully-connected classifier on top. The pre-trained model is "frozen" and only the weights of the classifier get updated during training.
# In this case, the convolutional base extracted all the features associated with each image and you just trained a classifier that determines the image class given that set of extracted features.
#
# * **Fine-tuning a pre-trained model**: To further improve performance, one might want to repurpose the top-level layers of the pre-trained models to the new dataset via fine-tuning.
# In this case, you tuned your weights such that your model learned high-level features specific to the dataset. This technique is usually recommended when the training dataset is large and very similar to the original dataset that the pre-trained model was trained on.
#
# To learn more, visit the [Transfer learning guide](https://www.tensorflow.org/guide/keras/transfer_learning).

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
  tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)
])

# show images
class_names = train_dataset.class_names
plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
