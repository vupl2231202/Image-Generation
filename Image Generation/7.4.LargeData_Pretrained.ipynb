# %%
# download data: https://drive.google.com/file/d/1ndExKmWJztgOQpO7iWFkkhaDnoTXaKWt/view?usp=sharing

# %% [markdown]
# # Use Pretrained Weight for Initialization

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf

from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
from google.colab import drive 
drive.mount('/content/gdrive')

# %%
#PATH = '/content/gdrive/My Drive/data/cats_and_dogs_small/'
PATH = 'cats_and_dogs_large/'

train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

BATCH_SIZE = 128
IMG_SIZE = (160, 160)
BUFFER_SIZE = BATCH_SIZE*5

train_dataset = image_dataset_from_directory(train_dir,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE)
# Out:
# Found 22000 files belonging to 2 classes.

# %%
validation_dataset = image_dataset_from_directory(validation_dir,
                                                  shuffle=True,
                                                  batch_size=BATCH_SIZE,
                                                  image_size=IMG_SIZE)
# Out:
# Found 3000 files belonging to 2 classes.

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
train_dataset = train_dataset.prefetch(buffer_size=BUFFER_SIZE)
validation_dataset = validation_dataset.prefetch(buffer_size=BUFFER_SIZE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %%
preprocess_input = tf.keras.applications.vgg16.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)

# %%
print(IMG_SIZE)
IMG_SHAPE = IMG_SIZE + (3,)
print(IMG_SHAPE)
# Out:
# (160, 160)
# (160, 160, 3)

# %%
# Create the base model from the pre-trained model MobileNet V2
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (128, 5, 5, 512)

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (128, 512)

# %%
prediction_layer = tf.keras.layers.Dense(1)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (128, 1)

# %%
inputs = tf.keras.Input(shape=(160, 160, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
base_learning_rate = 0.0001
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.RMSprop(lr=base_learning_rate/10),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 160, 160, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 160, 160, 3)       0
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 160, 160, 3)]     0
# _________________________________________________________________
# tf_op_layer_BiasAdd (TensorF [(None, 160, 160, 3)]     0
# _________________________________________________________________
# vgg16 (Functional)           (None, 5, 5, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 513
# =================================================================
# Total params: 14,715,201
# Trainable params: 14,715,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 28

# %%
history_fine = model.fit(train_dataset,
                         epochs=50,
                         validation_data=validation_dataset)
# Out:
# Epoch 1/50
#   2/172 [..............................] - ETA: 34s - loss: 2.7405 - accuracy: 0.5352WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1168s vs `on_train_batch_end` time: 0.2744s). Check your callbacks.
# 172/172 [==============================] - 75s 435ms/step - loss: 0.2906 - accuracy: 0.8899 - val_loss: 0.1187 - val_accuracy: 0.9543
# Epoch 2/50
# 172/172 [==============================] - 74s 429ms/step - loss: 0.1225 - accuracy: 0.9488 - val_loss: 0.0767 - val_accuracy: 0.9787
# Epoch 3/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0965 - accuracy: 0.9590 - val_loss: 0.0633 - val_accuracy: 0.9820
# Epoch 4/50
# 172/172 [==============================] - 73s 426ms/step - loss: 0.0785 - accuracy: 0.9684 - val_loss: 0.0657 - val_accuracy: 0.9773
# Epoch 5/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0715 - accuracy: 0.9708 - val_loss: 0.0523 - val_accuracy: 0.9840
# Epoch 6/50
# 172/172 [==============================] - 74s 427ms/step - loss: 0.0609 - accuracy: 0.9771 - val_loss: 0.0668 - val_accuracy: 0.9830
# Epoch 7/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0567 - accuracy: 0.9772 - val_loss: 0.0610 - val_accuracy: 0.9837
# Epoch 8/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0494 - accuracy: 0.9816 - val_loss: 0.0529 - val_accuracy: 0.9857
# Epoch 9/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0460 - accuracy: 0.9820 - val_loss: 0.0652 - val_accuracy: 0.9853
# Epoch 10/50
# 172/172 [==============================] - 74s 427ms/step - loss: 0.0398 - accuracy: 0.9846 - val_loss: 0.0674 - val_accuracy: 0.9847
# Epoch 11/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0391 - accuracy: 0.9842 - val_loss: 0.0594 - val_accuracy: 0.9853
# Epoch 12/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0350 - accuracy: 0.9863 - val_loss: 0.0546 - val_accuracy: 0.9867
# Epoch 13/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0321 - accuracy: 0.9871 - val_loss: 0.0693 - val_accuracy: 0.9843
# Epoch 14/50
# 172/172 [==============================] - 73s 427ms/step - loss: 0.0301 - accuracy: 0.9888 - val_loss: 0.0871 - val_accuracy: 0.9840
# Epoch 15/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0272 - accuracy: 0.9893 - val_loss: 0.0660 - val_accuracy: 0.9853
# Epoch 16/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0261 - accuracy: 0.9907 - val_loss: 0.0655 - val_accuracy: 0.9870
# Epoch 17/50
# 172/172 [==============================] - 73s 425ms/step - loss: 0.0227 - accuracy: 0.9909 - val_loss: 0.0952 - val_accuracy: 0.9813
# Epoch 18/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0238 - accuracy: 0.9905 - val_loss: 0.0629 - val_accuracy: 0.9890
# Epoch 19/50
# 172/172 [==============================] - 73s 426ms/step - loss: 0.0211 - accuracy: 0.9923 - val_loss: 0.0774 - val_accuracy: 0.9850
# Epoch 20/50
# 172/172 [==============================] - 74s 427ms/step - loss: 0.0200 - accuracy: 0.9921 - val_loss: 0.1029 - val_accuracy: 0.9827
# Epoch 21/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0176 - accuracy: 0.9933 - val_loss: 0.1005 - val_accuracy: 0.9847
# Epoch 22/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0171 - accuracy: 0.9933 - val_loss: 0.0788 - val_accuracy: 0.9880
# Epoch 23/50
# 172/172 [==============================] - 74s 427ms/step - loss: 0.0169 - accuracy: 0.9938 - val_loss: 0.0791 - val_accuracy: 0.9873
# Epoch 24/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0148 - accuracy: 0.9945 - val_loss: 0.0709 - val_accuracy: 0.9873
# Epoch 25/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0160 - accuracy: 0.9948 - val_loss: 0.0902 - val_accuracy: 0.9870
# Epoch 26/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0160 - accuracy: 0.9940 - val_loss: 0.1491 - val_accuracy: 0.9803
# Epoch 27/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0113 - accuracy: 0.9957 - val_loss: 0.0945 - val_accuracy: 0.9883
# Epoch 28/50
# 172/172 [==============================] - 73s 427ms/step - loss: 0.0116 - accuracy: 0.9956 - val_loss: 0.0991 - val_accuracy: 0.9870
# Epoch 29/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0137 - accuracy: 0.9957 - val_loss: 0.0866 - val_accuracy: 0.9857
# Epoch 30/50
# 172/172 [==============================] - 73s 427ms/step - loss: 0.0124 - accuracy: 0.9960 - val_loss: 0.0823 - val_accuracy: 0.9880
# Epoch 31/50
# 172/172 [==============================] - 74s 427ms/step - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.0912 - val_accuracy: 0.9883
# Epoch 32/50
# 172/172 [==============================] - 74s 427ms/step - loss: 0.0100 - accuracy: 0.9962 - val_loss: 0.1127 - val_accuracy: 0.9883
# Epoch 33/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 0.1272 - val_accuracy: 0.9840
# Epoch 34/50
# 172/172 [==============================] - 74s 427ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.1359 - val_accuracy: 0.9833
# Epoch 35/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.1099 - val_accuracy: 0.9850
# Epoch 36/50
# 172/172 [==============================] - 73s 427ms/step - loss: 0.0103 - accuracy: 0.9962 - val_loss: 0.1166 - val_accuracy: 0.9857
# Epoch 37/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.1413 - val_accuracy: 0.9823
# Epoch 38/50
# 172/172 [==============================] - 74s 427ms/step - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.1565 - val_accuracy: 0.9800
# Epoch 39/50
# 172/172 [==============================] - 73s 426ms/step - loss: 0.0096 - accuracy: 0.9967 - val_loss: 0.1181 - val_accuracy: 0.9843
# Epoch 40/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0095 - accuracy: 0.9966 - val_loss: 0.1210 - val_accuracy: 0.9860
# Epoch 41/50
# 172/172 [==============================] - 74s 427ms/step - loss: 0.0069 - accuracy: 0.9970 - val_loss: 0.1214 - val_accuracy: 0.9857
# Epoch 42/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.1167 - val_accuracy: 0.9863
# Epoch 43/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0102 - accuracy: 0.9970 - val_loss: 0.1092 - val_accuracy: 0.9877
# Epoch 44/50
# 172/172 [==============================] - 74s 427ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.1154 - val_accuracy: 0.9853
# Epoch 45/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.1534 - val_accuracy: 0.9853
# Epoch 46/50
# 172/172 [==============================] - 73s 427ms/step - loss: 0.0079 - accuracy: 0.9977 - val_loss: 0.2261 - val_accuracy: 0.9790
# Epoch 47/50
# 172/172 [==============================] - 74s 429ms/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 0.1372 - val_accuracy: 0.9870
# Epoch 48/50
# 172/172 [==============================] - 73s 427ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.1192 - val_accuracy: 0.9857
# Epoch 49/50
# 172/172 [==============================] - 74s 428ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.1047 - val_accuracy: 0.9850
# Epoch 50/50
# 172/172 [==============================] - 74s 429ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.1080 - val_accuracy: 0.9867

# %%
acc = history_fine.history['accuracy']
val_acc = history_fine.history['val_accuracy']

loss = history_fine.history['loss']
val_loss = history_fine.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## Summary
#
# * **Using a pre-trained model for feature extraction**:  When working with a small dataset, it is a common practice to take advantage of features learned by a model trained on a larger dataset in the same domain. This is done by instantiating the pre-trained model and adding a fully-connected classifier on top. The pre-trained model is "frozen" and only the weights of the classifier get updated during training.
# In this case, the convolutional base extracted all the features associated with each image and you just trained a classifier that determines the image class given that set of extracted features.
#
# * **Fine-tuning a pre-trained model**: To further improve performance, one might want to repurpose the top-level layers of the pre-trained models to the new dataset via fine-tuning.
# In this case, you tuned your weights such that your model learned high-level features specific to the dataset. This technique is usually recommended when the training dataset is large and very similar to the original dataset that the pre-trained model was trained on.
#
# To learn more, visit the [Transfer learning guide](https://www.tensorflow.org/guide/keras/transfer_learning).
