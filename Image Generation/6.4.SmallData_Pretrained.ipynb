# %%
# download data: https://drive.google.com/file/d/1U6WD6V563igKFUedzVT_hCvFeY2-tFE_/view?usp=sharing

# %% [markdown]
# # Use Pretrained Weight for Initialization

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf

from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
from google.colab import drive 
drive.mount('/content/gdrive')

# %%
#PATH = '/content/gdrive/My Drive/data/cats_and_dogs_small/'
PATH = 'cats_and_dogs_small/'

train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

BATCH_SIZE = 128
IMG_SIZE = (160, 160)
BUFFER_SIZE = BATCH_SIZE*5

train_dataset = image_dataset_from_directory(train_dir,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE)
# Out:
# Found 2000 files belonging to 2 classes.

# %%
validation_dataset = image_dataset_from_directory(validation_dir,
                                                  shuffle=True,
                                                  batch_size=BATCH_SIZE,
                                                  image_size=IMG_SIZE)
# Out:
# Found 1000 files belonging to 2 classes.

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
train_dataset = train_dataset.prefetch(buffer_size=BUFFER_SIZE)
validation_dataset = validation_dataset.prefetch(buffer_size=BUFFER_SIZE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %%
preprocess_input = tf.keras.applications.vgg16.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)

# %%
print(IMG_SIZE)
IMG_SHAPE = IMG_SIZE + (3,)
print(IMG_SHAPE)
# Out:
# (160, 160)
# (160, 160, 3)

# %%
# Create the base model from the pre-trained model MobileNet V2
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (128, 5, 5, 512)

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (128, 512)

# %%
prediction_layer = tf.keras.layers.Dense(1)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (128, 1)

# %%
inputs = tf.keras.Input(shape=(160, 160, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
base_learning_rate = 0.0001
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.RMSprop(lr=base_learning_rate/10),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 160, 160, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 160, 160, 3)       0
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 160, 160, 3)]     0
# _________________________________________________________________
# tf_op_layer_BiasAdd (TensorF [(None, 160, 160, 3)]     0
# _________________________________________________________________
# vgg16 (Functional)           (None, 5, 5, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 513
# =================================================================
# Total params: 14,715,201
# Trainable params: 14,715,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 28

# %%
history_fine = model.fit(train_dataset,
                         epochs=150,
                         validation_data=validation_dataset)
# Out:
# Epoch 1/150
#  2/16 [==>...........................] - ETA: 2s - loss: 6.1453 - accuracy: 0.5078WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1167s vs `on_train_batch_end` time: 0.2728s). Check your callbacks.
# 16/16 [==============================] - 10s 645ms/step - loss: 1.5194 - accuracy: 0.6590 - val_loss: 0.2708 - val_accuracy: 0.8900
# Epoch 2/150
# 16/16 [==============================] - 7s 465ms/step - loss: 0.3770 - accuracy: 0.8265 - val_loss: 0.1804 - val_accuracy: 0.9300
# Epoch 3/150
# 16/16 [==============================] - 7s 465ms/step - loss: 0.2849 - accuracy: 0.8735 - val_loss: 0.1314 - val_accuracy: 0.9400
# Epoch 4/150
# 16/16 [==============================] - 7s 469ms/step - loss: 0.2212 - accuracy: 0.9050 - val_loss: 0.1247 - val_accuracy: 0.9590
# Epoch 5/150
# 16/16 [==============================] - 8s 469ms/step - loss: 0.1797 - accuracy: 0.9195 - val_loss: 0.0868 - val_accuracy: 0.9550
# Epoch 6/150
# 16/16 [==============================] - 7s 469ms/step - loss: 0.1764 - accuracy: 0.9180 - val_loss: 0.1013 - val_accuracy: 0.9650
# Epoch 7/150
# 16/16 [==============================] - 8s 469ms/step - loss: 0.1304 - accuracy: 0.9480 - val_loss: 0.0890 - val_accuracy: 0.9670
# Epoch 8/150
# 16/16 [==============================] - 8s 472ms/step - loss: 0.1251 - accuracy: 0.9400 - val_loss: 0.1048 - val_accuracy: 0.9690
# Epoch 9/150
# 16/16 [==============================] - 7s 468ms/step - loss: 0.1037 - accuracy: 0.9565 - val_loss: 0.0754 - val_accuracy: 0.9730
# Epoch 10/150
# 16/16 [==============================] - 8s 471ms/step - loss: 0.1013 - accuracy: 0.9570 - val_loss: 0.0648 - val_accuracy: 0.9660
# Epoch 11/150
# 16/16 [==============================] - 8s 471ms/step - loss: 0.0892 - accuracy: 0.9620 - val_loss: 0.1502 - val_accuracy: 0.9570
# Epoch 12/150
# 16/16 [==============================] - 8s 471ms/step - loss: 0.0987 - accuracy: 0.9540 - val_loss: 0.0662 - val_accuracy: 0.9710
# Epoch 13/150
# 16/16 [==============================] - 8s 472ms/step - loss: 0.0747 - accuracy: 0.9705 - val_loss: 0.1687 - val_accuracy: 0.9590
# Epoch 14/150
# 16/16 [==============================] - 8s 474ms/step - loss: 0.0751 - accuracy: 0.9695 - val_loss: 0.0710 - val_accuracy: 0.9730
# Epoch 15/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0726 - accuracy: 0.9725 - val_loss: 0.0733 - val_accuracy: 0.9720
# Epoch 16/150
# 16/16 [==============================] - 8s 479ms/step - loss: 0.0696 - accuracy: 0.9685 - val_loss: 0.0789 - val_accuracy: 0.9790
# Epoch 17/150
# 16/16 [==============================] - 8s 478ms/step - loss: 0.0659 - accuracy: 0.9720 - val_loss: 0.0875 - val_accuracy: 0.9760
# Epoch 18/150
# 16/16 [==============================] - 8s 486ms/step - loss: 0.0570 - accuracy: 0.9760 - val_loss: 0.0919 - val_accuracy: 0.9770
# Epoch 19/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0431 - accuracy: 0.9860 - val_loss: 0.0719 - val_accuracy: 0.9760
# Epoch 20/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0643 - accuracy: 0.9740 - val_loss: 0.0822 - val_accuracy: 0.9770
# Epoch 21/150
# 16/16 [==============================] - 8s 481ms/step - loss: 0.0403 - accuracy: 0.9850 - val_loss: 0.0710 - val_accuracy: 0.9730
# Epoch 22/150
# 16/16 [==============================] - 8s 476ms/step - loss: 0.0488 - accuracy: 0.9825 - val_loss: 0.0599 - val_accuracy: 0.9770
# Epoch 23/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0480 - accuracy: 0.9790 - val_loss: 0.0552 - val_accuracy: 0.9830
# Epoch 24/150
# 16/16 [==============================] - 8s 487ms/step - loss: 0.0380 - accuracy: 0.9865 - val_loss: 0.0849 - val_accuracy: 0.9780
# Epoch 25/150
# 16/16 [==============================] - 8s 476ms/step - loss: 0.0312 - accuracy: 0.9870 - val_loss: 0.0725 - val_accuracy: 0.9760
# Epoch 26/150
# 16/16 [==============================] - 8s 477ms/step - loss: 0.0242 - accuracy: 0.9870 - val_loss: 0.0724 - val_accuracy: 0.9760
# Epoch 27/150
# 16/16 [==============================] - 8s 486ms/step - loss: 0.0398 - accuracy: 0.9850 - val_loss: 0.1254 - val_accuracy: 0.9710
# Epoch 28/150
# 16/16 [==============================] - 8s 472ms/step - loss: 0.0431 - accuracy: 0.9840 - val_loss: 0.0819 - val_accuracy: 0.9700
# Epoch 29/150
# 16/16 [==============================] - 8s 480ms/step - loss: 0.0332 - accuracy: 0.9865 - val_loss: 0.0651 - val_accuracy: 0.9800
# Epoch 30/150
# 16/16 [==============================] - 8s 486ms/step - loss: 0.0206 - accuracy: 0.9925 - val_loss: 0.1561 - val_accuracy: 0.9660
# Epoch 31/150
# 16/16 [==============================] - 8s 489ms/step - loss: 0.0235 - accuracy: 0.9910 - val_loss: 0.1213 - val_accuracy: 0.9710
# Epoch 32/150
# 16/16 [==============================] - 8s 476ms/step - loss: 0.0242 - accuracy: 0.9895 - val_loss: 0.0732 - val_accuracy: 0.9780
# Epoch 33/150
# 16/16 [==============================] - 8s 486ms/step - loss: 0.0355 - accuracy: 0.9850 - val_loss: 0.0866 - val_accuracy: 0.9750
# Epoch 34/150
# 16/16 [==============================] - 8s 476ms/step - loss: 0.0259 - accuracy: 0.9905 - val_loss: 0.1008 - val_accuracy: 0.9710
# Epoch 35/150
# 16/16 [==============================] - 8s 485ms/step - loss: 0.0112 - accuracy: 0.9970 - val_loss: 0.0731 - val_accuracy: 0.9820
# Epoch 36/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0200 - accuracy: 0.9940 - val_loss: 0.0586 - val_accuracy: 0.9810
# Epoch 37/150
# 16/16 [==============================] - 8s 489ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0814 - val_accuracy: 0.9780
# Epoch 38/150
# 16/16 [==============================] - 8s 483ms/step - loss: 0.0183 - accuracy: 0.9925 - val_loss: 0.1029 - val_accuracy: 0.9770
# Epoch 39/150
# 16/16 [==============================] - 8s 473ms/step - loss: 0.0302 - accuracy: 0.9880 - val_loss: 0.0616 - val_accuracy: 0.9800
# Epoch 40/150
# 16/16 [==============================] - 8s 476ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.1370 - val_accuracy: 0.9660
# Epoch 41/150
# 16/16 [==============================] - 8s 477ms/step - loss: 0.0180 - accuracy: 0.9930 - val_loss: 0.0921 - val_accuracy: 0.9760
# Epoch 42/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.2808 - val_accuracy: 0.9560
# Epoch 43/150
# 16/16 [==============================] - 8s 490ms/step - loss: 0.0155 - accuracy: 0.9930 - val_loss: 0.0584 - val_accuracy: 0.9830
# Epoch 44/150
# 16/16 [==============================] - 8s 484ms/step - loss: 0.0073 - accuracy: 0.9980 - val_loss: 0.1405 - val_accuracy: 0.9690
# Epoch 45/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0206 - accuracy: 0.9930 - val_loss: 0.1225 - val_accuracy: 0.9680
# Epoch 46/150
# 16/16 [==============================] - 8s 478ms/step - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.0857 - val_accuracy: 0.9780
# Epoch 47/150
# 16/16 [==============================] - 8s 476ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.0632 - val_accuracy: 0.9810
# Epoch 48/150
# 16/16 [==============================] - 8s 485ms/step - loss: 0.0068 - accuracy: 0.9985 - val_loss: 0.0789 - val_accuracy: 0.9790
# Epoch 49/150
# 16/16 [==============================] - 8s 473ms/step - loss: 0.0367 - accuracy: 0.9855 - val_loss: 0.0869 - val_accuracy: 0.9770
# Epoch 50/150
# 16/16 [==============================] - 8s 487ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0998 - val_accuracy: 0.9790
# Epoch 51/150
# 16/16 [==============================] - 8s 502ms/step - loss: 0.0078 - accuracy: 0.9965 - val_loss: 0.0696 - val_accuracy: 0.9790
# Epoch 52/150
# 16/16 [==============================] - 8s 474ms/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 0.0969 - val_accuracy: 0.9780
# Epoch 53/150
# 16/16 [==============================] - 8s 474ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.0840 - val_accuracy: 0.9770
# Epoch 54/150
# 16/16 [==============================] - 8s 481ms/step - loss: 0.0094 - accuracy: 0.9955 - val_loss: 0.0861 - val_accuracy: 0.9780
# Epoch 55/150
# 16/16 [==============================] - 8s 488ms/step - loss: 0.0108 - accuracy: 0.9935 - val_loss: 0.1060 - val_accuracy: 0.9760
# Epoch 56/150
# 16/16 [==============================] - 8s 488ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0984 - val_accuracy: 0.9800
# Epoch 57/150
# 16/16 [==============================] - 8s 486ms/step - loss: 0.0409 - accuracy: 0.9895 - val_loss: 0.0643 - val_accuracy: 0.9790
# Epoch 58/150
# 16/16 [==============================] - 8s 487ms/step - loss: 0.0074 - accuracy: 0.9965 - val_loss: 0.0768 - val_accuracy: 0.9780
# Epoch 59/150
# 16/16 [==============================] - 8s 482ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0749 - val_accuracy: 0.9800
# Epoch 60/150
# 16/16 [==============================] - 8s 479ms/step - loss: 0.0088 - accuracy: 0.9965 - val_loss: 0.1100 - val_accuracy: 0.9730
# Epoch 61/150
# 16/16 [==============================] - 8s 479ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.0733 - val_accuracy: 0.9830
# Epoch 62/150
# 16/16 [==============================] - 8s 483ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1129 - val_accuracy: 0.9840
# Epoch 63/150
# 16/16 [==============================] - 8s 487ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1095 - val_accuracy: 0.9810
# Epoch 64/150
# 16/16 [==============================] - 8s 474ms/step - loss: 0.0410 - accuracy: 0.9885 - val_loss: 0.0670 - val_accuracy: 0.9820
# Epoch 65/150
# 16/16 [==============================] - 8s 479ms/step - loss: 0.0051 - accuracy: 0.9990 - val_loss: 0.0914 - val_accuracy: 0.9790
# Epoch 66/150
# 16/16 [==============================] - 8s 485ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0915 - val_accuracy: 0.9820
# Epoch 67/150
# 16/16 [==============================] - 8s 477ms/step - loss: 0.0131 - accuracy: 0.9945 - val_loss: 0.0724 - val_accuracy: 0.9800
# Epoch 68/150
# 16/16 [==============================] - 8s 490ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.1027 - val_accuracy: 0.9800
# Epoch 69/150
# 16/16 [==============================] - 8s 485ms/step - loss: 0.0106 - accuracy: 0.9960 - val_loss: 0.0804 - val_accuracy: 0.9790
# Epoch 70/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0753 - val_accuracy: 0.9800
# Epoch 71/150
# 16/16 [==============================] - 8s 472ms/step - loss: 6.1184e-04 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9780
# Epoch 72/150
# 16/16 [==============================] - 8s 490ms/step - loss: 0.0267 - accuracy: 0.9935 - val_loss: 0.0624 - val_accuracy: 0.9810
# Epoch 73/150
# 16/16 [==============================] - 8s 474ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0997 - val_accuracy: 0.9740
# Epoch 74/150
# 16/16 [==============================] - 8s 474ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.2149 - val_accuracy: 0.9630
# Epoch 75/150
# 16/16 [==============================] - 8s 478ms/step - loss: 0.0103 - accuracy: 0.9975 - val_loss: 0.0786 - val_accuracy: 0.9810
# Epoch 76/150
# 16/16 [==============================] - 8s 484ms/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.0771 - val_accuracy: 0.9790
# Epoch 77/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0656 - val_accuracy: 0.9800
# Epoch 78/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.2117 - val_accuracy: 0.9650
# Epoch 79/150
# 16/16 [==============================] - 8s 478ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.0924 - val_accuracy: 0.9820
# Epoch 80/150
# 16/16 [==============================] - 8s 491ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.0876 - val_accuracy: 0.9810
# Epoch 81/150
# 16/16 [==============================] - 8s 474ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0895 - val_accuracy: 0.9800
# Epoch 82/150
# 16/16 [==============================] - 8s 477ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 0.5591 - val_accuracy: 0.9300
# Epoch 83/150
# 16/16 [==============================] - 8s 490ms/step - loss: 0.0201 - accuracy: 0.9945 - val_loss: 0.0754 - val_accuracy: 0.9780
# Epoch 84/150
# 16/16 [==============================] - 8s 473ms/step - loss: 4.8973e-04 - accuracy: 1.0000 - val_loss: 0.0968 - val_accuracy: 0.9750
# Epoch 85/150
# 16/16 [==============================] - 8s 473ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1077 - val_accuracy: 0.9810
# Epoch 86/150
# 16/16 [==============================] - 8s 477ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0900 - val_accuracy: 0.9800
# Epoch 87/150
# 16/16 [==============================] - 8s 489ms/step - loss: 0.0196 - accuracy: 0.9955 - val_loss: 0.0704 - val_accuracy: 0.9830
# Epoch 88/150
# 16/16 [==============================] - 8s 472ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0772 - val_accuracy: 0.9800
# Epoch 89/150
# 16/16 [==============================] - 8s 479ms/step - loss: 4.1615e-04 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 0.9790
# Epoch 90/150
# 16/16 [==============================] - 8s 489ms/step - loss: 0.0124 - accuracy: 0.9945 - val_loss: 0.0910 - val_accuracy: 0.9790
# Epoch 91/150
# 16/16 [==============================] - 8s 473ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9790
# Epoch 92/150
# 16/16 [==============================] - 8s 478ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.1079 - val_accuracy: 0.9790
# Epoch 93/150
# 16/16 [==============================] - 8s 484ms/step - loss: 5.0374e-04 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9790
# Epoch 94/150
# 16/16 [==============================] - 8s 477ms/step - loss: 0.0022 - accuracy: 0.9985 - val_loss: 0.1203 - val_accuracy: 0.9810
# Epoch 95/150
# 16/16 [==============================] - 8s 481ms/step - loss: 0.0088 - accuracy: 0.9965 - val_loss: 0.1007 - val_accuracy: 0.9830
# Epoch 96/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9710
# Epoch 97/150
# 16/16 [==============================] - 8s 476ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.1098 - val_accuracy: 0.9780
# Epoch 98/150
# 16/16 [==============================] - 8s 487ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.1066 - val_accuracy: 0.9820
# Epoch 99/150
# 16/16 [==============================] - 8s 474ms/step - loss: 6.4700e-04 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9810
# Epoch 100/150
# 16/16 [==============================] - 8s 484ms/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.1192 - val_accuracy: 0.9820
# Epoch 101/150
# 16/16 [==============================] - 8s 478ms/step - loss: 7.7253e-04 - accuracy: 1.0000 - val_loss: 0.0893 - val_accuracy: 0.9850
# Epoch 102/150
# 16/16 [==============================] - 8s 472ms/step - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.0987 - val_accuracy: 0.9840
# Epoch 103/150
# 16/16 [==============================] - 8s 480ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 0.0921 - val_accuracy: 0.9840
# Epoch 104/150
# 16/16 [==============================] - 8s 478ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.1191 - val_accuracy: 0.9840
# Epoch 105/150
# 16/16 [==============================] - 8s 479ms/step - loss: 0.0064 - accuracy: 0.9975 - val_loss: 0.0835 - val_accuracy: 0.9810
# Epoch 106/150
# 16/16 [==============================] - 8s 475ms/step - loss: 3.3371e-04 - accuracy: 1.0000 - val_loss: 0.0877 - val_accuracy: 0.9830
# Epoch 107/150
# 16/16 [==============================] - 8s 479ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.0879 - val_accuracy: 0.9820
# Epoch 108/150
# 16/16 [==============================] - 8s 487ms/step - loss: 2.1338e-04 - accuracy: 1.0000 - val_loss: 0.0929 - val_accuracy: 0.9810
# Epoch 109/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0038 - accuracy: 0.9980 - val_loss: 0.0798 - val_accuracy: 0.9790
# Epoch 110/150
# 16/16 [==============================] - 8s 478ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 0.0865 - val_accuracy: 0.9780
# Epoch 111/150
# 16/16 [==============================] - 8s 483ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 0.0940 - val_accuracy: 0.9780
# Epoch 112/150
# 16/16 [==============================] - 8s 478ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1115 - val_accuracy: 0.9770
# Epoch 113/150
# 16/16 [==============================] - 8s 474ms/step - loss: 3.8286e-04 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 0.9770
# Epoch 114/150
# 16/16 [==============================] - 8s 476ms/step - loss: 0.0081 - accuracy: 0.9955 - val_loss: 0.0901 - val_accuracy: 0.9780
# Epoch 115/150
# 16/16 [==============================] - 8s 474ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 0.1205 - val_accuracy: 0.9760
# Epoch 116/150
# 16/16 [==============================] - 8s 478ms/step - loss: 6.4014e-04 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9790
# Epoch 117/150
# 16/16 [==============================] - 8s 476ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1045 - val_accuracy: 0.9790
# Epoch 118/150
# 16/16 [==============================] - 8s 477ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.1101 - val_accuracy: 0.9800
# Epoch 119/150
# 16/16 [==============================] - 8s 477ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0951 - val_accuracy: 0.9810
# Epoch 120/150
# 16/16 [==============================] - 8s 488ms/step - loss: 2.3939e-04 - accuracy: 1.0000 - val_loss: 0.0885 - val_accuracy: 0.9800
# Epoch 121/150
# 16/16 [==============================] - 8s 474ms/step - loss: 6.9894e-04 - accuracy: 1.0000 - val_loss: 0.1091 - val_accuracy: 0.9810
# Epoch 122/150
# 16/16 [==============================] - 8s 476ms/step - loss: 9.1026e-05 - accuracy: 1.0000 - val_loss: 0.1184 - val_accuracy: 0.9820
# Epoch 123/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0158 - accuracy: 0.9960 - val_loss: 0.1018 - val_accuracy: 0.9770
# Epoch 124/150
# 16/16 [==============================] - 8s 476ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 0.0973 - val_accuracy: 0.9780
# Epoch 125/150
# 16/16 [==============================] - 8s 472ms/step - loss: 7.6551e-04 - accuracy: 0.9995 - val_loss: 0.1037 - val_accuracy: 0.9800
# Epoch 126/150
# 16/16 [==============================] - 8s 483ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.1179 - val_accuracy: 0.9780
# Epoch 127/150
# 16/16 [==============================] - 8s 488ms/step - loss: 0.0055 - accuracy: 0.9990 - val_loss: 0.1064 - val_accuracy: 0.9790
# Epoch 128/150
# 16/16 [==============================] - 8s 477ms/step - loss: 5.5821e-04 - accuracy: 1.0000 - val_loss: 0.1780 - val_accuracy: 0.9700
# Epoch 129/150
# 16/16 [==============================] - 8s 478ms/step - loss: 5.1750e-04 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9750
# Epoch 130/150
# 16/16 [==============================] - 8s 473ms/step - loss: 3.4803e-04 - accuracy: 0.9995 - val_loss: 0.1768 - val_accuracy: 0.9750
# Epoch 131/150
# 16/16 [==============================] - 8s 487ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 0.2675 - val_accuracy: 0.9690
# Epoch 132/150
# 16/16 [==============================] - 8s 476ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1295 - val_accuracy: 0.9790
# Epoch 133/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0107 - accuracy: 0.9970 - val_loss: 0.1180 - val_accuracy: 0.9790
# Epoch 134/150
# 16/16 [==============================] - 8s 479ms/step - loss: 0.0031 - accuracy: 0.9985 - val_loss: 0.1314 - val_accuracy: 0.9770
# Epoch 135/150
# 16/16 [==============================] - 8s 474ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.1157 - val_accuracy: 0.9740
# Epoch 136/150
# 16/16 [==============================] - 8s 475ms/step - loss: 0.0034 - accuracy: 0.9985 - val_loss: 0.1788 - val_accuracy: 0.9710
# Epoch 137/150
# 16/16 [==============================] - 8s 476ms/step - loss: 4.3988e-04 - accuracy: 1.0000 - val_loss: 0.1044 - val_accuracy: 0.9770
# Epoch 138/150
# 16/16 [==============================] - 8s 477ms/step - loss: 1.0632e-04 - accuracy: 1.0000 - val_loss: 0.1066 - val_accuracy: 0.9750
# Epoch 139/150
# 16/16 [==============================] - 8s 486ms/step - loss: 1.8932e-04 - accuracy: 1.0000 - val_loss: 0.1599 - val_accuracy: 0.9760
# Epoch 140/150
# 16/16 [==============================] - 8s 480ms/step - loss: 0.0157 - accuracy: 0.9935 - val_loss: 0.0904 - val_accuracy: 0.9770
# Epoch 141/150
# 16/16 [==============================] - 8s 483ms/step - loss: 5.0679e-04 - accuracy: 0.9995 - val_loss: 0.1316 - val_accuracy: 0.9780
# Epoch 142/150
# 16/16 [==============================] - 8s 476ms/step - loss: 7.9412e-04 - accuracy: 1.0000 - val_loss: 0.1069 - val_accuracy: 0.9750
# Epoch 143/150
# 16/16 [==============================] - 8s 478ms/step - loss: 2.1961e-04 - accuracy: 1.0000 - val_loss: 0.1084 - val_accuracy: 0.9770
# Epoch 144/150
# 16/16 [==============================] - 8s 473ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0816 - val_accuracy: 0.9830
# Epoch 145/150
# 16/16 [==============================] - 8s 480ms/step - loss: 2.0817e-04 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9820
# Epoch 146/150
# 16/16 [==============================] - 8s 471ms/step - loss: 0.0086 - accuracy: 0.9955 - val_loss: 0.1527 - val_accuracy: 0.9750
# Epoch 147/150
# 16/16 [==============================] - 8s 480ms/step - loss: 0.0019 - accuracy: 0.9990 - val_loss: 0.1443 - val_accuracy: 0.9780
# Epoch 148/150
# 16/16 [==============================] - 8s 491ms/step - loss: 3.4555e-04 - accuracy: 1.0000 - val_loss: 0.1266 - val_accuracy: 0.9780
# Epoch 149/150
# 16/16 [==============================] - 8s 476ms/step - loss: 2.8853e-04 - accuracy: 1.0000 - val_loss: 0.1758 - val_accuracy: 0.9720
# Epoch 150/150
# 16/16 [==============================] - 8s 474ms/step - loss: 0.0054 - accuracy: 0.9970 - val_loss: 0.1004 - val_accuracy: 0.9840

# %%
acc = history_fine.history['accuracy']
val_acc = history_fine.history['val_accuracy']

loss = history_fine.history['loss']
val_loss = history_fine.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## Summary
#
# * **Using a pre-trained model for feature extraction**:  When working with a small dataset, it is a common practice to take advantage of features learned by a model trained on a larger dataset in the same domain. This is done by instantiating the pre-trained model and adding a fully-connected classifier on top. The pre-trained model is "frozen" and only the weights of the classifier get updated during training.
# In this case, the convolutional base extracted all the features associated with each image and you just trained a classifier that determines the image class given that set of extracted features.
#
# * **Fine-tuning a pre-trained model**: To further improve performance, one might want to repurpose the top-level layers of the pre-trained models to the new dataset via fine-tuning.
# In this case, you tuned your weights such that your model learned high-level features specific to the dataset. This technique is usually recommended when the training dataset is large and very similar to the original dataset that the pre-trained model was trained on.
#
# To learn more, visit the [Transfer learning guide](https://www.tensorflow.org/guide/keras/transfer_learning).
